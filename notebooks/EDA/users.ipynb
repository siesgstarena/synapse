# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# c:\Users\salman\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
RAW_DATA_PATH = "../../data/raw/"

# %%
users_df = pd.read_csv(RAW_DATA_PATH + "users.csv")

# %%
users_df.head()
# Out:
#    __v                       _id  \
# 0    0  5b5c89298114180020d4bcb0
# 1    0  5b5ca6857cf0b100209fe499
# 2    0  5b5d74e337392f89933e7511
# 3    0  5b5d750b37392f89933e7512
# 4    0  5b5d752b37392f89933e7513
#
#                                                about  \
# 0  Founder of SIESGSTarena, Software Engineer @ C...
# 1                                            Meow :3
# 2               Full Stack, both in career and life.
# 3                             @sudocoder98 on GitHub
# 4                                                NaN
#
#                   createdAt                              email  \
# 0  2018-07-28T09:48:01.849Z       omkar.prabhu15@siesgst.ac.in
# 1  2018-07-28T11:53:17.815Z       rahul.sawant17@siesgst.ac.in
# 2  2018-07-22T02:22:27.599Z         dubey.vishal@siesgst.ac.in
# 3  2018-07-21T10:58:13.697Z  siddharth.poduval15@siesgst.ac.in
# 4  2018-07-22T04:03:38.790Z        pritam.negi15@siesgst.ac.in
#
#                                            followers  \
# 0  [{"$oid":"5b647d5e58d190002048aabc"},{"$oid":"...
# 1  [{"$oid":"5b64786a58d190002048aab7"},{"$oid":"...
# 2                                                 []
# 3                                                 []
# 4              [{"$oid":"5b5d756b37392f89933e7515"}]
#
#                                            following identicon  \
# 0  [{"$oid":"5b5ca6857cf0b100209fe499"},{"$oid":"...       NaN
# 1  [{"$oid":"5b5c89298114180020d4bcb0"},{"$oid":"...       NaN
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                 name  notifications.activities  ...  \
# 0       Omkar Prabhu                      True  ...
# 1  Rahul Sawantdesai                      True  ...
# 2       Vishal Dubey                      True  ...
# 3  Siddharth Poduval                      True  ...
# 4        Pritam Negi                      True  ...
#
#                                             password ratings social.codechef  \
# 0  $2a$10$rOCbOa1JQm0I.jhEcXziZOv.DqktR7YqM6TGX8q...       0     prabhuomkar
# 1  $2a$10$qSzbhkTetfo.ND1RLpxaX.7o5vVfQrCmaAU3hrq...       0          rsd511
# 2  $2a$10$EObroSAabyRbIJ9YIqrVOOgu3A/M4E7BXn0LScE...       0             NaN
# 3  $2a$10$ZpixTO7ED3I6b6uPnpla4u9.VfoDOk6FxarAoYs...       0             NaN
# 4  $2a$10$Weo71HuQyFhcWliWIL8D1ePywld1mJnLza4N0p3...    1405             NaN
#
#    social.codefoces social.codeforces  social.github  \
# 0               NaN       prabhuomkar    prabhuomkar
# 1               NaN            rsd511         rsd511
# 2               NaN               NaN            NaN
# 3               NaN               NaN            NaN
# 4               NaN               NaN            NaN
#
#                                               topics  \
# 0  ["graphs","dp","geometry","webdev","ml","dl","...
# 1                     ["graphs","dp","dl","ml","ai"]
# 2                                                NaN
# 3                                                NaN
# 4  ["graphs","strings","number theory","maths","a...
#
#                   updatedAt           username verified
# 0  2021-05-04T16:02:15.042Z        prabhuomkar     True
# 1  2020-04-19T08:31:37.294Z             rsd511     True
# 2  2018-07-23T07:48:42.357Z  NustaAndroidFreak     True
# 3  2018-12-18T04:06:39.503Z          sudocoder     True
# 4  2019-01-09T09:32:24.217Z        pritam_negi     True
#
# [5 rows x 22 columns]
