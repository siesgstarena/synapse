# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# c:\Users\salman\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
col_name = ["ProblemId","C","C++","Go","Java","Javascript","Python","Python3"]
df = pd.read_csv('../../data/processed/success_score.csv')
df.rename(columns = {'Unnamed: 0':'problemId'}, inplace = True)
df
# Out:
#                     problemId         C       C++        Go      Java  \
# 0    5b5c8cd7276e2200208fed62  0.708418  0.741621  0.674481  0.730613
# 1    5b645f711b2cd40020b6c771  0.697211  0.780235  0.663106  0.698383
# 2    5b649819c0b1b80020eb30e1  0.782912  0.729926  0.697609  0.702172
# 3    5b64600d1b2cd40020b6c772  0.736975  0.736975  0.624211  0.701462
# 4    5b6c3ec18cab100020e963b7  0.707936  0.753305  0.676529  0.738346
# ..                        ...       ...       ...       ...       ...
# 199  63361b9a125f8a00222e06ef  0.660756  0.791391  0.660756  0.880797
# 200  633620e3fe6e62002205e71e  0.669491  0.738728  0.669491  0.669491
# 201  6336ad26ee62f10022c977c2  0.705785  0.747667  0.705785  0.705785
# 202  6336b760ee62f10022c97c37  0.683354  0.759061  0.683354  0.683354
# 203  6336c0b1f9be3c00226020f2  0.731059  0.731059  0.731059  0.731059
#
#      Javascript    Python   Python3
# 0      0.674481  0.674481  0.763862
# 1      0.663106  0.890666  0.741500
# ...

# %%
df.describe()
# Out:
#                 C         C++          Go        Java  Javascript      Python  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.704334    0.750738    0.688965    0.731316    0.684595    0.686746
# std      0.046229    0.057939    0.047726    0.067173    0.032995    0.041203
# min      0.622459    0.642960    0.622459    0.622459    0.622459    0.622459
# 25%      0.677937    0.721152    0.660756    0.695437    0.660756    0.660756
# 50%      0.702063    0.733347    0.681512    0.716736    0.679698    0.679698
# 75%      0.724180    0.762232    0.705785    0.741552    0.705286    0.705785
# max      0.980708    0.999665    0.999997    0.994256    0.897982    0.988587
#
#           Python3
# count  204.000000
# mean     0.740666
# std      0.036715
# min      0.622459
# 25%      0.723389
# 50%      0.731884
# 75%      0.747282
# max      0.926574

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df.drop(['problemId'], axis=1)
Y = df['problemId']

# %%
X
# Out:
#             C       C++        Go      Java  Javascript    Python   Python3
# 0    0.708418  0.741621  0.674481  0.730613    0.674481  0.674481  0.763862
# 1    0.697211  0.780235  0.663106  0.698383    0.663106  0.890666  0.741500
# 2    0.782912  0.729926  0.697609  0.702172    0.697609  0.697609  0.747527
# 3    0.736975  0.736975  0.624211  0.701462    0.624211  0.624211  0.736975
# 4    0.707936  0.753305  0.676529  0.738346    0.676529  0.676529  0.785069
# ..        ...       ...       ...       ...         ...       ...       ...
# 199  0.660756  0.791391  0.660756  0.880797    0.660756  0.660756  0.660756
# 200  0.669491  0.738728  0.669491  0.669491    0.669491  0.669491  0.669491
# 201  0.705785  0.747667  0.705785  0.705785    0.705785  0.705785  0.705785
# 202  0.683354  0.759061  0.683354  0.683354    0.683354  0.683354  0.683354
# 203  0.731059  0.731059  0.731059  0.731059    0.731059  0.731059  0.731059
#
# [204 rows x 7 columns]

# %%
Y.columns = ['problemId']
Y
# Out:
# 0      5b5c8cd7276e2200208fed62
# 1      5b645f711b2cd40020b6c771
# 2      5b649819c0b1b80020eb30e1
# 3      5b64600d1b2cd40020b6c772
# 4      5b6c3ec18cab100020e963b7
#                  ...
# 199    63361b9a125f8a00222e06ef
# 200    633620e3fe6e62002205e71e
# 201    6336ad26ee62f10022c977c2
# 202    6336b760ee62f10022c97c37
# 203    6336c0b1f9be3c00226020f2
# Name: problemId, Length: 204, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_test)

# %%
y_pred
# Out:
# array(['6065cf6645a5d100227e079b', '6256b3db9f86540024c5653f',
#        '5d3c780e7cb1120022007f29', '63309926ab6261002246d343',
#        '6065d73145a5d100227e079f', '6335f3dd125f8a00222e06eb',
#        '5b714d3c155c0000206d76fc', '6055bd3d3d00c8002293e4d3',
#        '6336ad26ee62f10022c977c2', '5e2d29af533c8d0022c770fe',
#        '6065e97c45a5d100227e07bd', '63308b35ab6261002246d32d',
#        '6055b8213d00c8002293e4ce', '6055c43ecef4570022ac9c14',
#        '5f368132d83e600022d1b148', '5b96a51f9808fa0020a42972',
#        '618e8b9e7793650023873244', '62550242ff3fbf0024dfddd7',
#        '618e8b9e7793650023873244', '602f54d1eb158c002271b46b',
#        '5d3c84697cb1120022007f30', '602f53f4eb158c002271b46a',
#        '613b7375f969d70023246c88', '618e85c97793650023873240',
#        '5e6e0be659366b002223786e', '6255b691aa9acd0024d4166c',
#        '6217c009a5433500245d867b', '5d623acae007440022d873c0',
#        '602f504deb158c002271b467', '5e98a5f03af9550022fc130c',
# ...

# %%
y_test
# Out:
# 18     5bae773afda1fc0021bbf24a
# 45     5ca063dd08f90d00223749ea
# 33     5c39f4af80aaed0022b63275
# 37     5c7abbd75dfcc900221e1119
# 109    5fbf9d829296860022aa89db
# 90     5f6ad8a34bf84b0022982aff
# 5      5b6c3fc08cab100020e963b8
# 124    6055b90e3d00c8002293e4cf
# 12     5b96a9e0e701a900207872a7
# 153    618ec686dfc674002301c26b
# 61     5d7a635db112e300220a44d2
# 187    63309651ab6261002246d342
# 166    621a24954323e500241da25d
# 160    61fe3451aa33750024aa513d
# 155    61d9c8cf2d678f002403d077
# 7      5b72e7f9750b6100209d9f12
# 129    6065da6245a5d100227e07a7
# 131    6065d6f645a5d100227e079e
# 75     5e80968d99770c00221d371e
# 66     5e2d10a1533c8d0022c770f2
# 44     5c98eb0d16c4b60022cd52f0
# 146    614cb2c0b93b4e00230e2782
# 63     5e15ed4773aedb002281070f
# 135    610eae514575780022cbbdd1
# 86     5f353ac472b45b0022f74c5f
# 141    613b4d6df969d70023246c83
# 188    6330dde45766d0002293b565
# 182    6301e8473a18140022ffed0d
# 161    61fe5beeaa33750024aa515b
# ...

# %%
for yp in y_pred:
    print(df[df['problemId'] == yp])
# Out:
#                     problemId         C       C++        Go      Java  \
# 126  6065cf6645a5d100227e079b  0.705785  0.718517  0.663162  0.774744
#
#      Javascript    Python   Python3
# 126    0.663162  0.663162  0.738774
#                     problemId         C       C++        Go      Java  \
# 174  6256b3db9f86540024c5653f  0.691353  0.771107  0.691353  0.702616
#
#      Javascript    Python   Python3
# 174    0.691353  0.691353  0.691353
#                    problemId         C       C++        Go     Java  \
# 47  5d3c780e7cb1120022007f29  0.700934  0.721164  0.664863  0.75137
#
#     Javascript    Python   Python3
# 47    0.897982  0.664863  0.758548
#                     problemId         C       C++        Go      Java  \
# 196  63309926ab6261002246d343  0.704052  0.763357  0.704052  0.740465
#
#      Javascript    Python   Python3
# 196    0.704052  0.704052  0.710005
#                     problemId         C       C++        Go      Java  \
# ...

# %%
y_pred
# Out:
# array(['6065cf6645a5d100227e079b', '6256b3db9f86540024c5653f',
#        '5d3c780e7cb1120022007f29', '63309926ab6261002246d343',
#        '6065d73145a5d100227e079f', '6335f3dd125f8a00222e06eb',
#        '5b714d3c155c0000206d76fc', '6055bd3d3d00c8002293e4d3',
#        '6336ad26ee62f10022c977c2', '5e2d29af533c8d0022c770fe',
#        '6065e97c45a5d100227e07bd', '63308b35ab6261002246d32d',
#        '6055b8213d00c8002293e4ce', '6055c43ecef4570022ac9c14',
#        '5f368132d83e600022d1b148', '5b96a51f9808fa0020a42972',
#        '618e8b9e7793650023873244', '62550242ff3fbf0024dfddd7',
#        '618e8b9e7793650023873244', '602f54d1eb158c002271b46b',
#        '5d3c84697cb1120022007f30', '602f53f4eb158c002271b46a',
#        '613b7375f969d70023246c88', '618e85c97793650023873240',
#        '5e6e0be659366b002223786e', '6255b691aa9acd0024d4166c',
#        '6217c009a5433500245d867b', '5d623acae007440022d873c0',
#        '602f504deb158c002271b467', '5e98a5f03af9550022fc130c',
# ...

# %%
df.iloc[0]
# Out:
# problemId     5b5c8cd7276e2200208fed62
# C                             0.708418
# C++                           0.741621
# Go                            0.674481
# Java                          0.730613
# Javascript                    0.674481
# Python                        0.674481
# Python3                       0.763862
# Name: 0, dtype: object

# %%
gnb.predict((x_test.iloc[0]).to_numpy().reshape(1, -1))
# Out:
# c:\Users\salman\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['6065cf6645a5d100227e079b'], dtype='<U24')

# %%
(x_test.iloc[0]).to_numpy()
# Out:
# array([0.7098387 , 0.73059917, 0.66476802, 0.75764437, 0.66476802,
#        0.66476802, 0.7644216 ])

# %%
df[df['problemId'] == '6065cf6645a5d100227e079b']
# Out:
#                     problemId         C       C++        Go      Java  \
# 126  6065cf6645a5d100227e079b  0.705785  0.718517  0.663162  0.774744
#
#      Javascript    Python   Python3
# 126    0.663162  0.663162  0.738774

# %%
from sklearn import metrics
def EvaluateModel(df,y_pred,x_test):
    temp = []
    t = []
    a = []
    b = []
    for i,prob in enumerate(y_pred):
        curProb = x_test.iloc[i]
        actualProblem = df[(df['C'] == curProb['C'])
        & (df['C++'] == curProb['C++'])
        & (df['Go'] == curProb['Go'])
        & (df['Java'] == curProb['Java'])
        & (df['Javascript'] == curProb['Javascript'])
        & (df['Python'] == curProb['Python'])
        & (df['Python3'] == curProb['Python3'])]['problemId']
        # print(actualProblem.head())
        predProblem = df[df['problemId'] == prob]['problemId']
        # diff = 1 + np.subtract(df[df.problemId == actualProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop() , df[df.problemId == predProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop())
        # temp.append(diff**2 / 6)
        diff = np.subtract(df[df.problemId == actualProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop() , df[df.problemId == predProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop())
        # print((abs(np.sum(np.abs((diff))))))
        t.append(((np.sum(np.abs((diff))))))
        temp.append(True if ((np.sum(np.abs((diff)))) < 0.049141336850275 ) else False)
        a.append(df[df.problemId == actualProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop())
        b.append(df[df.problemId == predProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop())
    # print((np.mean(temp) / np.sum(temp))*100)
    print(temp.count(True),len(temp),np.mean(t))
    print(metrics.accuracy_score(a, b),a,b)

# %%
EvaluateModel(df,y_pred,x_test)
# Out:
# 20 41 0.06437438300738745
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\salman\OneDrive\Desktop\Recommendation-system\notebooks\training\naive.ipynb Cell 20 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/salman/OneDrive/Desktop/Recommendation-system/notebooks/training/naive.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> EvaluateModel(df,y_pred,x_test)
#
# c:\Users\salman\OneDrive\Desktop\Recommendation-system\notebooks\training\naive.ipynb Cell 20 in EvaluateModel(df, y_pred, x_test)
#      <a href='vscode-notebook-cell:/c%3A/Users/salman/OneDrive/Desktop/Recommendation-system/notebooks/training/naive.ipynb#X25sZmlsZQ%3D%3D?line=25'>26</a> # print((np.mean(temp) / np.sum(temp))*100)
# ...

# %%
df[(df['problemId'] == '6065cf6645a5d100227e079b') | (df['problemId'] == '5bae773afda1fc0021bbf24a')]
# Out:
#                     problemId         C       C++        Go      Java  \
# 18   5bae773afda1fc0021bbf24a  0.709839  0.730599  0.664768  0.757644
# 126  6065cf6645a5d100227e079b  0.705785  0.718517  0.663162  0.774744
#
#      Javascript    Python   Python3
# 18     0.664768  0.664768  0.764422
# 126    0.663162  0.663162  0.738774

# %%
from sklearn import metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import max_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_poisson_deviance
from sklearn.metrics import mean_gamma_deviance

def EvalM(df,y_pred,y_test):
    y1 = []
    y2 = []
    for i,prob in enumerate(y_pred):
        predProblem = df[df['problemId'] == prob]['problemId']
        actualProblem = df[df['problemId'] == y_test.iloc[i]]['problemId']
        y1.append(np.sum(df[df.problemId == actualProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop()))
        y2.append(np.sum(df[df.problemId == predProblem.values[0]].drop(['problemId'], axis=1).values.tolist().pop()))
    print(metrics.mean_squared_error(y1, y2))
    print(metrics.r2_score(y1, y2))
    print(metrics.mean_absolute_error(y1, y2))
    print(metrics.median_absolute_error(y1, y2))
    print(metrics.max_error(y1, y2))
    print(metrics.explained_variance_score(y1, y2))
    print(np.std(y1),np.std(y2))

# %%
EvalM(df,y_pred,y_test)
# Out:
# 0.001968171840696721
# 0.9119219098595736
# 0.029809389568566956
# 0.01627947538858532
# 0.1861061276445346
# 0.9135921362518278
# 0.14948498165598118 0.1412909862129384

# %%
from sklearn.neighbors import NearestNeighbors
def recommend(problemId):
    y_pred = []
    model = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(x_train)
    distances, indices = model.kneighbors(x_train)
    # for i in range(len(distances)):
    #     y_pred.append(y_train.iloc[indices[i][0]])
    for i in range(len(distances)):
        if y_train.iloc[i] == problemId:
            y_pred.append(y_train.iloc[indices[i][0]])
    return y_pred

# %%
y_knn_pred = recommend('6065cf6645a5d100227e079b')

# %%
# EvalM(df,y_knn_pred,y_test)
y_knn_pred
# Out:
# [126    6065cf6645a5d100227e079b
#  Name: problemId, dtype: object]
