# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# c:\Users\salman\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
RAW_DATA_PATH = "../../data/raw/"

# %%
contest_df = pd.read_csv(RAW_DATA_PATH + "contests.csv")

# %%
contest_df.head()
# Out:
#    __v                       _id  \
# 0    0  5b5c89ef30db8a0020962414
# 1    0  5b5ca6d47cf0b100209fe49a
# 2    0  5b5dc464e608dd0020ec2c73
# 3    0  5b5dc4dce608dd0020ec2c74
# 4    0  5b5dc535e608dd0020ec2c75
#
#                                         announcement      code  \
# 0                                                     UNIVERSE
# 1   Give your feedback here: <a href="https://goo...     AUG18
# 2  Give your feedback here: <a href="https://goo....     SRM01
# 3  <center>\r\n<b>01:40 PM</b>: Check your submis...    SEPT18
# 4  First 4 submissions made at the start are reju...     SRM03
#
#                                         contestAdmin  \
# 0  [{"$oid":"5b6d84eb2e9049002068df33"},{"$oid":"...
# 1                           5b5ca6857cf0b100209fe499
# 2              [{"$oid":"5b5d756037392f89933e7514"}]
# 3                           5b66d36591c77d0020b63d0b
# 4                           5b6490e95969e7002076f330
#
# ...
