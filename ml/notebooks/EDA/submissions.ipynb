# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# c:\Users\salman\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
RAW_DATA_PATH = "../../data/raw/"

# %%
submissions_df = pd.read_csv(RAW_DATA_PATH + "submissions.csv")

# %%
submissions_df.head()
# Out:
#    __v                       _id                 contestId  \
# 0    0  5b608157e228ec0020a1fcf5  5b5c89ef30db8a0020962414
# 1    0  5b649806c0b1b80020eb30e0  5b5c89ef30db8a0020962414
# 2    0  5b6499a9eae2320020c43e8a  5b5c89ef30db8a0020962414
# 3    0  5b649eebeae2320020c43e8f  5b5c89ef30db8a0020962414
# 4    0  5b64a0d8eae2320020c43e91  5b5c89ef30db8a0020962414
#
#                   createdAt  duringContest  \
# 0  2018-07-31T10:03:43.362Z           True
# 1  2018-08-03T12:29:34.750Z           True
# 2  2018-08-03T12:36:33.554Z           True
# 3  2018-08-03T12:58:59.425Z           True
# 4  2018-08-03T13:07:12.145Z           True
#
#                                          fileContent language  memory  \
# 0  https://firebasestorage.googleapis.com/v0/b/si...    C++14  3452KB
# 1  https://firebasestorage.googleapis.com/v0/b/si...        C     0KB
# 2  https://firebasestorage.googleapis.com/v0/b/si...        C     0KB
# 3  https://firebasestorage.googleapis.com/v0/b/si...        C  9416KB
# 4  https://firebasestorage.googleapis.com/v0/b/si...        C  9416KB
#
#                                               output  points  \
# 0  https://firebasestorage.googleapis.com/v0/b/si...       0
# 1  https://firebasestorage.googleapis.com/v0/b/si...       0
# 2  https://firebasestorage.googleapis.com/v0/b/si...       0
# 3  https://firebasestorage.googleapis.com/v0/b/si...       0
# 4  https://firebasestorage.googleapis.com/v0/b/si...       0
#
#                   problemId               status time  \
# 0  5b5c8cd7276e2200208fed62             Accepted   0s
# 1  5b5c8cd7276e2200208fed62  Time Limit Exceeded   0s
# 2  5b5c8cd7276e2200208fed62  Time Limit Exceeded   0s
# 3  5b5c8cd7276e2200208fed62         Wrong Answer   0s
# 4  5b5c8cd7276e2200208fed62             Accepted   0s
#
#                   updatedAt                    userId
# 0  2018-11-11T06:21:18.721Z  5b5d756037392f89933e7514
# 1  2018-11-11T06:21:18.621Z  5b6490e95969e7002076f330
# 2  2018-11-11T06:21:18.656Z  5b6490e95969e7002076f330
# 3  2018-11-11T06:21:19.140Z  5b6490e95969e7002076f330
# 4  2018-11-11T06:21:18.574Z  5b6490e95969e7002076f330
